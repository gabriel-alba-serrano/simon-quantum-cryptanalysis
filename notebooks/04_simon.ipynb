# %% [markdown]
# # Simon
#
# Recover the hidden XOR period from a toy Simon oracle.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'src'))

from simon_qcrypto.algorithms.simon.experiments import run_experiment

result = run_experiment(input_bits=3, secret=0b011, seed=13)
result

# %% [markdown]
# ## Circuit diagram
#
# Draw the Simon circuit for the same hidden XOR period.

# %%
from simon_qcrypto.algorithms.simon.oracles import generate_problem
from simon_qcrypto.algorithms.simon.quantum import build_circuit

problem = generate_problem(input_bits=3, secret=0b011, seed=13)
circuit = build_circuit(problem, measure=True)
circuit.draw('mpl', fold=-1, idle_wires=False)
