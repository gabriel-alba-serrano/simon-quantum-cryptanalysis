# %% [markdown]
# # Quantum Fourier Transform
#
# Compare the exact NumPy amplitudes with the Qiskit statevector.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'src'))

from simon_qcrypto.algorithms.qft.experiments import run_experiment

result = run_experiment(num_qubits=3, basis_state=5, seed=5)
result
# Out:
# ExperimentResult(name='qft', mode='statevector', success=True, problem={'num_qubits': 3, 'basis_state': 5, 'seed': 5}, classical_result={'basis_state': '101', 'amplitudes': array([ 3.53553391e-01+0.00000000e+00j, -3.53553391e-01+2.16489014e-16j,
#         1.08244507e-16+3.53553391e-01j, -9.52770505e-16-3.53553391e-01j,
#        -2.50000000e-01-2.50000000e-01j,  2.50000000e-01+2.50000000e-01j,
#         2.50000000e-01-2.50000000e-01j, -2.50000000e-01+2.50000000e-01j]), 'ordering': 'qiskit_little_endian'}, quantum_result={'amplitudes': array([ 3.53553391e-01+0.j        , -3.53553391e-01+0.j        ,
#         2.16489014e-17+0.35355339j, -2.16489014e-17-0.35355339j,
#        -2.50000000e-01-0.25j      ,  2.50000000e-01+0.25j      ,
#         2.50000000e-01-0.25j      , -2.50000000e-01+0.25j      ]), 'query_count': 0}, metadata={})

# %% [markdown]
# ## Circuit diagram
#
# Draw the QFT circuit applied to the selected basis state.

# %%
from simon_qcrypto.algorithms.qft.oracles import generate_problem
from simon_qcrypto.algorithms.qft.quantum import build_circuit

problem = generate_problem(num_qubits=3, basis_state=5, seed=5)
circuit = build_circuit(problem, measure=False)
circuit.draw('mpl', fold=-1, idle_wires=False)
