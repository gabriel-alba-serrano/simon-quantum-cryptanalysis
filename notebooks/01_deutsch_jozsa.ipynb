# %% [markdown]
# # Deutsch-Jozsa
#
# Run the toy Deutsch-Jozsa experiment in exact simulation mode.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'src'))

from simon_qcrypto.algorithms.deutsch_jozsa.experiments import run_experiment

result = run_experiment(num_qubits=3, oracle_type='balanced', seed=7)
result
# Out:
# ExperimentResult(name='deutsch_jozsa', mode='statevector', success=True, problem={'num_qubits': 3, 'oracle_type': 'balanced', 'truth_table': {0: 0, 1: 1, 2: 1, 3: 0, 4: 1, 5: 1, 6: 0, 7: 0}, 'seed': 7}, classical_result={'classification': 'balanced', 'queries': 8, 'truth_table': {0: 0, 1: 1, 2: 1, 3: 0, 4: 1, 5: 1, 6: 0, 7: 0}}, quantum_result={'classification': 'balanced', 'probabilities': {'010': 0.24999999999999933, '011': 0.24999999999999942, '110': 0.24999999999999947, '111': 0.24999999999999925}, 'query_count': 1}, metadata={})

# %% [markdown]
# ## Circuit diagram
#
# Rebuild the same oracle instance and draw the measured Deutsch-Jozsa circuit.

# %%
from simon_qcrypto.algorithms.deutsch_jozsa.oracles import generate_problem
from simon_qcrypto.algorithms.deutsch_jozsa.quantum import build_circuit

problem = generate_problem(num_qubits=3, oracle_type='balanced', seed=7)
circuit = build_circuit(problem, measure=True)
circuit.draw('mpl', fold=-1, idle_wires=False)
