# %% [markdown]
# # Bernstein-Vazirani
#
# Recover a hidden linear string with one quantum query.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'src'))

from simon_qcrypto.algorithms.bernstein_vazirani.experiments import run_experiment

result = run_experiment(num_qubits=4, secret=0b1011, bias=1, seed=11)
result
# Out:
# ExperimentResult(name='bernstein_vazirani', mode='statevector', success=True, problem={'num_qubits': 4, 'secret': 11, 'bias': 1, 'seed': 11}, classical_result={'secret': '1011', 'bias': 1, 'queries': 5}, quantum_result={'secret': '1011', 'probabilities': {'1011': 0.9999999999999986}, 'query_count': 1}, metadata={'bias_is_global_phase': True})

# %% [markdown]
# ## Circuit diagram
#
# Draw the Bernstein-Vazirani circuit for the same hidden string.

# %%
from simon_qcrypto.algorithms.bernstein_vazirani.oracles import generate_problem
from simon_qcrypto.algorithms.bernstein_vazirani.quantum import build_circuit

problem = generate_problem(num_qubits=4, secret=0b1011, bias=1, seed=11)
circuit = build_circuit(problem, measure=True)
circuit.draw('mpl', fold=-1, idle_wires=False)
